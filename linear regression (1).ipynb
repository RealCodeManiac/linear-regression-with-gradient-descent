# %%
print("Example of Linear Regression with Gradient Descent")
# Out:
# Example of Linear Regression with Gradient Descent

# %%
import numpy as np
#numpy is the only library we need to complete this project
x_values = [3,7,2,8,9,1,5]
#x_values are the independent variable
y_values = [6,14,4,16,18,2,10]
#y_values are the dependent variables 
learning_rate = 0.001
#learning rate should set by experimenting with it. A popular example is to start with a high learning rate and go low
iterations = 1000
#iterations is the number of times you want to train something

def iteration():
    m = 0
    b = 0
    #this function trains the gradient descent function 1000 times to imporve accuracy
    
    for n in range(iterations+1):
        gradient_descent(m,b)
        m,b = gradient_descent(m,b)
        
    
def gradient_descent(m,b):
    #this is the gradient descent function. It takes the derivative of the error which is the actual y minus the guess with some inital m and b value.
    # after taking the partial derivative of the error function with respect to m and b we update the m and b values by that much over a number of times
    for i in range(7):
        x = x_values[i]
        y = y_values[i]
        guess = m*x+b
        error = y - guess
        m = m + error*x*learning_rate
        b = b + error*learning_rate
        print("The error is ",error)
        print("The m is ",m)
        print("The b is ",b)
        return m,b
        
iteration()
# Out:
# The error is  6
# The m is  0.018000000000000002
# The b is  0.006
# The error is  6
# The m is  0.018000000000000002
# The b is  0.006
# The error is  5.94
# The m is  0.035820000000000005
# The b is  0.011940000000000001
# The error is  5.94
# The m is  0.035820000000000005
# The b is  0.011940000000000001
# The error is  5.8806
# The m is  0.053461800000000004
# The b is  0.017820600000000002
# The error is  5.8806
# The m is  0.053461800000000004
# The b is  0.017820600000000002
# The error is  5.821794
# The m is  0.070927182
# The b is  0.023642394000000004
# The error is  5.821794
# The m is  0.070927182
# The b is  0.023642394000000004
# The error is  5.76357606
# The m is  0.08821791018000001
# The b is  0.029405970060000005
# The error is  5.76357606
# The m is  0.08821791018000001
# The b is  0.029405970060000005
# The error is  5.7059402994
# The m is  0.10533573107820002
# The b is  0.035111910359400006
# The error is  5.7059402994
# The m is  0.10533573107820002
# ...
